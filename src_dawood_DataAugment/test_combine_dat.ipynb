# %%
import torch
from utils import TrajectoriesDataset  
from utils import set_seeds
from models_evaluation import Policy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

config= {
        "feedback_type": 'cloning_10',
        "task": 'intro_test',
        "episodes": 50, #
        "static_env": False,
        "headless_env": False,
        "proprio_dim": 8,
        "action_dim": 7,
        "visual_embedding_dim": 256,
        "learning_rate": 3e-4,
        "weight_decay": 3e-6,
        "batch_size": 8,#16
    }

# replay_memory_10 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_1.dat")

# model_path = "data/intro_test/cloning_10_policy.pt"

# policy = Policy(config)

# policy.load_state_dict(torch.load(model_path))

# print(f'length of demos {len(replay_memory_10)}')

# %%
replay_memory_1 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_1.dat")
replay_memory_2 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_2.dat")
replay_memory_3 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_3.dat")
replay_memory_4 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_4.dat")
replay_memory_5 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_5.dat")
replay_memory_6 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_6.dat")
replay_memory_7 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_7.dat")
replay_memory_8 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_8.dat")
replay_memory_9 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_9.dat")
replay_memory_10 = torch.load("/home/faps/CEILing/CEILing256_v2/data/dat_bowen/demos_10_10.dat")

demos_100 = replay_memory_1

print(f'length of demos {len(demos_100)}')

for i in range(len(replay_memory_2)):
    camera_obs, proprio_obs, action, feedback=replay_memory_2[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')
    

for i in range(len(replay_memory_3)):
    camera_obs, proprio_obs, action, feedback=replay_memory_3[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')

for i in range(len(replay_memory_4)):
    camera_obs, proprio_obs, action, feedback=replay_memory_4[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')

for i in range(len(replay_memory_5)):
    camera_obs, proprio_obs, action, feedback=replay_memory_5[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')
    

for i in range(len(replay_memory_6)):
    camera_obs, proprio_obs, action, feedback=replay_memory_6[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')

for i in range(len(replay_memory_7)):
    camera_obs, proprio_obs, action, feedback=replay_memory_7[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')

for i in range(len(replay_memory_8)):
    camera_obs, proprio_obs, action, feedback=replay_memory_8[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')
    

for i in range(len(replay_memory_9)):
    camera_obs, proprio_obs, action, feedback=replay_memory_9[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')

for i in range(len(replay_memory_10)):
    camera_obs, proprio_obs, action, feedback=replay_memory_10[i]
    demos_100.camera_obs.append(camera_obs)
    demos_100.proprio_obs.append(proprio_obs)
    demos_100.action.append(action)
    demos_100.feedback.append(feedback)

print(f'length of demos {len(demos_100)}')

torch.save(demos_100, "demos_100_1.dat")
# Out:
# length of demos 10
# length of demos 20
# length of demos 30
# length of demos 40
# length of demos 50
# length of demos 60
# length of demos 70
# length of demos 80
# length of demos 90
# length of demos 100
